# %%
from MFEA_lib.tasks.Benchmark.IDPC_EDU import IDPC_EDU_benchmark
from MFEA_lib.model import MFEA_base, SA_MFEA, MFEA1
from MFEA_lib.model.utils import *
from MFEA_lib.operators.Crossover import *
from MFEA_lib.operators.Mutation import *
from MFEA_lib.operators.Selection import *

# %%
tasks, IndClass = IDPC_EDU_benchmark.get_tasks(2)
# Out:
# Reading data...
# 100%|██████████| 18/18 [01:32<00:00,  5.16s/it]

# %%
len(tasks)
# Out:
# 18

# %%
baseModel = MFEA_base.model()
baseModel.compile(
    IndClass= IndClass,
    tasks= tasks,
    # crossover= newSBX(nc = 2, gamma= 0.4, alpha= 6),
    crossover= IDPCEDU_Crossover(),
    mutation= IDPCEDU_Mutation(),
    selection= ElitismSelection()
)
solve = baseModel.fit(
    nb_generations = 5000, rmp = 0.3, nb_inds_each_task= 10, 
    bound_pop= [0, 1], evaluate_initial_skillFactor= True
)
# Out:
# Time: 00m 11.92s    8 % [=>                  ]  Cost: 1.15E+02  1.02E+02  1.15E+02  5.40E+01  5.30E+01  5.30E+01  6.70E+01  7.10E+01  6.50E+01  7.40E+01  7.20E+01  7.10E+01  8.30E+01  8.20E+01  9.90E+01  9.30E+01  1.00E+02  9.10E+01  ,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2. Subject HUST/5. TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb Cell 4' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=0'>1</a> baseModel = MFEA_base.model()
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=1'>2</a> baseModel.compile(
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=2'>3</a>     IndClass= IndClass,
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=3'>4</a>     tasks= tasks,
#    (...)
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=7'>8</a>     selection= ElitismSelection()
#       <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=8'>9</a> )
# ---> <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=9'>10</a> solve = baseModel.fit(
#      <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=10'>11</a>     nb_generations = 5000, rmp = 0.3, nb_inds_each_task= 10,
#      <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=11'>12</a>     bound_pop= [0, 1], evaluate_initial_skillFactor= True
#      <a href='vscode-notebook-cell:/mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/8_IDPC_DU.ipynb#ch0000003?line=12'>13</a> )
#
# File /mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2. Subject HUST/5. TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py:67, in model.fit(self, nb_generations, rmp, nb_inds_each_task, evaluate_initial_skillFactor, *args, **kwargs)
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py?line=63'>64</a> population.update_rank()
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py?line=65'>66</a> # selection
# ---> <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py?line=66'>67</a> self.selection(population, [nb_inds_each_task] * len(self.tasks))
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py?line=68'>69</a> # update operators
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/model/MFEA_base.py?line=69'>70</a> self.crossover.update(population = population)
#
# File /mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2. Subject HUST/5. TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py:26, in ElitismSelection.__call__(self, population, nb_inds_tasks, *args, **kwds)
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py?line=23'>24</a> def __call__(self, population:Population, nb_inds_tasks: list, *args, **kwds) -> list[int]:
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py?line=24'>25</a>     ls_idx_selected = []
# ---> <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py?line=25'>26</a>     for idx_subpop, subpop in enumerate(population):
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py?line=26'>27</a>         N_i = min(nb_inds_tasks[idx_subpop], len(subpop))
#      <a href='file:///mnt/ee1bd79c-6956-419b-951b-4699528687d7/Project/2.%20Subject%20HUST/5.%20TULKH/IDPCEDU-TULKH/MFEA_lib/operators/Selection.py?line=28'>29</a>         # on top
#
# KeyboardInterrupt:

# %%
baseModel.render_history()

# %%
baseModel = SA_MFEA.model()
baseModel.compile(
    IndClass= IndClass,
    tasks= tasks,
    # crossover= newSBX(nc = 2, gamma= 0.4, alpha= 6),
    crossover= IDPCEDU_Crossover(),
    mutation= IDPCEDU_Mutation(),
    selection= ElitismSelection()
)
solve = baseModel.fit(
    max_inds_each_task= list(np.zeros(shape= (len(tasks),), dtype= int) + 4),
    min_inds_each_task= list(np.zeros(shape= (len(tasks),), dtype= int) + 4),
    max_eval_each_task= list(np.zeros(shape= (len(tasks),), dtype= int) + 500 * 4 ),
    log_oneline= True,
    num_epochs_printed= 1,
    evaluate_initial_skillFactor= True,
    LSA= True
)
# Out:
# 'Time: 00m 8.23s '
# ' 98 % [===================>]  '
# 'cost: 1.30E+01  1.20E+01  1.30E+01  1.60E+01  1.60E+01  1.80E+01  2.50E+01  2.10E+01  2.20E+01  2.80E+01  2.60E+01  2.70E+01  3.30E+01  4.10E+01  3.50E+01  4.60E+01  4.10E+01  5.00E+01  4.60E+01  4.20E+01  4.20E+01  4.90E+01  4.60E+01  5.00E+01  ,  '
# End

# %%
smpModel = SMP_MFEA.model()

smpModel.compile(
    IndClass= IndClass,
    tasks= tasks,
    # tasks = GECCO20_benchmark_50tasks.get_items(ID = id),
    # crossover= SBX_Crossover(nc = 2),
    crossover= newSBX(nc = 2, gamma= 0.4, alpha = 6),
    mutation = GaussMutation(scale = 0.1),
    selection= ElitismSelection(random_percent= 0.),
    search = SHADE(len_mem= 30, p_ontop= 0.1)
)
smpModel.fit(
    nb_generations= 1000, nb_inds_each_task= 100, nb_inds_min= 30,
    lr = 0.15, p_const_intra= 0., p_mutate= 0.1, prob_search = 0.,
    nb_epochs_stop= 1000, swap_po= False,
    evaluate_initial_skillFactor= True
)
# Out:
# Checking...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_118622/475217337.py in <module>
#      11     search = SHADE(len_mem= 30, p_ontop= 0.1)
#      12 )
# ---> 13 smpModel.fit(
#      14     nb_generations= 1000, nb_inds_each_task= 100, nb_inds_min= 30,
#      15     lr = 0.15, p_const_intra= 0., p_mutate= 0.1, prob_search = 0.,
#
# /mnt/ee1bd79c-6956-419b-951b-4699528687d7/MFEA_MSO/MFEA_lib/model/SMP_MFEA.py in fit(self, nb_generations, nb_inds_each_task, nb_inds_min, lr, p_const_intra, swap_po, p_mutate, prob_search, nb_epochs_stop, evaluate_initial_skillFactor, *args, **kwargs)
#     221                         pa, pb = pb, pa
#     222
# --> 223                     oa, ob = self.crossover(pa, pb, skf_pa, skf_pa)
#     224
#     225                     # add oa, ob to offsprings population and eval fcost
#
# /mnt/ee1bd79c-6956-419b-951b-4699528687d7/MFEA_MSO/MFEA_lib/operators/Crossover.py in __call__(self, pa, pb, skf_oa, skf_ob, *args, **kwargs)
#     167             idx_crossover = np.random.rand(self.dim_uss) < self.prob[pa.skill_factor, pb.skill_factor]
#     168
# --> 169             if np.all(idx_crossover == 0) or np.all(pa[idx_crossover] == pb[idx_crossover]):
#     170                 # alway crossover -> new individual
#     171                 idx_notsame = np.where(pa.genes != pb.genes)[0].tolist()
#
# /mnt/ee1bd79c-6956-419b-951b-4699528687d7/MFEA_MSO/MFEA_lib/EA.py in __getitem__(self, index)
#      33         return len(self.genes)
#      34     def __getitem__(self, index):
# ---> 35         return self.genes[index]
#      36
#      37     def __add__(self, other):
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 45
